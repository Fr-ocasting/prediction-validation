# %%
import torch 
import time
from utilities_DL import get_DataSet_and_invalid_dates,get_MultiModel_loss_args_emb_opts
from DL_class import MultiModelTrainer, Trainer
from config import get_args
from plotting import plot_k_fold_split
from save_results import update_results_df
from paths import folder_path,file_name

import torch.nn as nn
import torch.nn.functional as F
import pandas as pd

# Load config
model_name = 'STGCN' #'CNN'
args = get_args(model_name)

# Modification : 
args.epochs = 50
args.K_fold = 6
args.batch_size = 256
args.ray = False
args.memory_format_last = True

def complete_train(args,folder_path,file_name):
    # Load Multi-DataSet,k_fold split:
    t0 = time.time()
    dataset,invalid_dates = get_DataSet_and_invalid_dates(args.abs_path, folder_path,file_name,args.W,args.D,args.H,args.step_ahead,single_station = False)
    print(f"Time to compute 'get_DataSet_and_invalid_dates': {time.time()-t0}")

    t0 = time.time()
    (Datasets,DataLoader_list,time_slots_labels_list,dic_class2rpz_list,dic_rpz2class_list,nb_words_embedding_list) =  dataset.split_K_fold(args,invalid_dates)
    print(f"Time to compute 'split_K_fold': {time.time()-t0}")

    t0 = time.time()
    (loss_function,Model_list,Optimizer_list,Scheduler_list,args_embedding) = get_MultiModel_loss_args_emb_opts(args,nb_words_embedding_list,dic_class2rpz_list,n_vertex = len(Datasets[0].columns))
    print(f"Time to compute 'get_MultiModel_loss_args_emb_opts': {time.time()-t0}")

    # Get First dataset, dataloader etc:
    model = Model_list[0].to(args.device)
    data_loader = DataLoader_list[0]
    optimizer = Optimizer_list[0]
    dic_class2rpz = dic_class2rpz_list[0]
    
    t1 = time.time()
    if args.torch_compile:
        model = torch.compile(model,backend=args.backend)
    trainer = Trainer(Datasets[0],model,data_loader,args,optimizer,loss_function,scheduler = None,args_embedding = args_embedding)
    trainer.train_and_valid(mod = None, mod_plot = None,station = 0)
    print('torch training: ',time.time()-t1)
    pd.DataFrame({'valid': trainer.valid_loss}).plot()
    
    return(trainer)
# Out:
# Training and Hyper-parameter tuning with Ray is not possible

# %% [markdown]
# # Test sur STGCN
# ## Sans optimisation :

# %%
args.num_workers = 0
args.persistent_workers = False
args.pin_memory = False
args.prefetch_factor = None

args.autocast = False

args.non_blocking = False
args.torch_compile = False

trainer = complete_train(args,folder_path,file_name)
# Out:
# coverage period: 2019-01-01 00:00:00 - 2020-01-01 00:00:00
# Time-step per hour: 4.0
# Time to compute 'get_DataSet_and_invalid_dates': 0.17162108421325684
# Time to compute 'split_K_fold': 8.525211811065674
# Time to compute 'get_MultiModel_loss_args_emb_opts': 0.0668940544128418
# start training
#
# Max GPU memory allocated: 5.026412010192871 GB
# Max GPU memory cached: 7.744140625 GB
# Max CPU memory allocated: 4.450130462646484 GB
# None
# torch training:  82.98163104057312

# %% [markdown]
# ## Après optimisation
#
# ### Utilisation de num-workers = 1:
# Peu d'amélioration notable

# %%
args.num_workers = 1
args.persistent_workers = True
args.pin_memory = True
args.prefetch_factor = 2

args.autocast = True
args.non_blocking = False
args.torch_compile = False

trainer = complete_train(args,folder_path,file_name)
# Out:
# coverage period: 2019-01-01 00:00:00 - 2020-01-01 00:00:00
# Time-step per hour: 4.0
# Time to compute 'get_DataSet_and_invalid_dates': 0.16309261322021484
# Time to compute 'split_K_fold': 8.520658016204834
# Time to compute 'get_MultiModel_loss_args_emb_opts': 0.20531058311462402
# start training
#
# Max GPU memory allocated: 5.032680034637451 GB
# Max GPU memory cached: 7.75 GB
# Max CPU memory allocated: 4.585899353027344 GB
# None
# torch training:  81.99344754219055

# %% [markdown]
# ### Utilisation de Mixed-precision avec autocast()
# Peu d'amélioration notable

# %%
args.num_workers = 0
args.persistent_workers = 0
args.pin_memory = 0
args.prefetch_factor = None

args.autocast = True
args.non_blocking = False
args.torch_compile = False

trainer = complete_train(args,folder_path,file_name)
# Out:
# coverage period: 2019-01-01 00:00:00 - 2020-01-01 00:00:00
# Time-step per hour: 4.0
# Time to compute 'get_DataSet_and_invalid_dates': 0.16931390762329102
# Time to compute 'split_K_fold': 8.570596694946289
# Time to compute 'get_MultiModel_loss_args_emb_opts': 0.07871174812316895
# start training
#
# Max GPU memory allocated: 5.032680034637451 GB
# Max GPU memory cached: 7.75 GB
# Max CPU memory allocated: 4.60101318359375 GB
# None
# torch training:  80.68810892105103

# %% [markdown]
# ## Utilisation de Non-Blocking:

# %%
args.num_workers = 0
args.persistent_workers = 0
args.pin_memory = 0
args.prefetch_factor = None

args.autocast = False
args.non_blocking = True
args.torch_compile = False

trainer = complete_train(args,folder_path,file_name)
# Out:
# coverage period: 2019-01-01 00:00:00 - 2020-01-01 00:00:00
# Time-step per hour: 4.0
# Time to compute 'get_DataSet_and_invalid_dates': 0.15339112281799316
# Time to compute 'split_K_fold': 7.882626533508301
# Time to compute 'get_MultiModel_loss_args_emb_opts': 0.06003284454345703
# start training
#
# Max GPU memory allocated: 5.032680034637451 GB
# Max GPU memory cached: 7.751953125 GB
# Max CPU memory allocated: 4.605419158935547 GB
# None
# torch training:  79.09807181358337

# %% [markdown]
# ## Utilisation des 3:
# Toujours d'aucune utilité

# %%
args.num_workers = 1
args.persistent_workers = True
args.pin_memory = True
args.prefetch_factor = 2

args.autocast = True
args.non_blocking = True
args.torch_compile = False

trainer = complete_train(args,folder_path,file_name)
# Out:
# coverage period: 2019-01-01 00:00:00 - 2020-01-01 00:00:00
# Time-step per hour: 4.0
# Time to compute 'get_DataSet_and_invalid_dates': 0.33345723152160645
# Time to compute 'split_K_fold': 7.929331064224243
# Time to compute 'get_MultiModel_loss_args_emb_opts': 0.06128668785095215
# start training
#
# Max GPU memory allocated: 5.032680034637451 GB
# Max GPU memory cached: 7.751953125 GB
# Max CPU memory allocated: 4.6179351806640625 GB
# None
# torch training:  81.53136014938354

# %%
args.num_workers = 2
args.persistent_workers = True
args.pin_memory = True
args.prefetch_factor = 3

args.autocast = True
args.non_blocking = True
args.torch_compile = False

trainer = complete_train(args,folder_path,file_name)
# Out:
# coverage period: 2019-01-01 00:00:00 - 2020-01-01 00:00:00
# Time-step per hour: 4.0
# Time to compute 'get_DataSet_and_invalid_dates': 0.1846606731414795
# Time to compute 'split_K_fold': 8.191544532775879
# Time to compute 'get_MultiModel_loss_args_emb_opts': 0.06245303153991699
# start training

# %%
args.num_workers = 6
args.persistent_workers = True
args.pin_memory = True
args.prefetch_factor = 3

args.autocast = True
args.non_blocking = True
args.torch_compile = False

trainer = complete_train(args,folder_path,file_name)

# %% [markdown]
# ## Utilisation de Torch.compile:
# Inutile + explosions de la consommation Memoire GPU pour bakcend = 'cudagraphs'

# %%
import torch._dynamo as torchdynamo
torchdynamo.config.suppress_errors = True
torchdynamo.reset()

args.num_workers = 1
args.persistent_workers = True
args.pin_memory = True
args.prefetch_factor = 2

args.autocast = True
args.torch_compile = True
args.backend = 'inductor'

trainer = complete_train(args,folder_path,file_name)
# Out:
# coverage period: 2019-01-01 00:00:00 - 2020-01-01 00:00:00
# Time-step per hour: 4.0
# Time to compute 'get_DataSet_and_invalid_dates': 0.26770448684692383
# Time to compute 'split_K_fold': 7.876119613647461
# Time to compute 'get_MultiModel_loss_args_emb_opts': 1.544926404953003
# start training
# [2024-06-17 19:22:25,028] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT forward /home/rrochas/uncertainty_quantification/dl_models/full_model.py line 21
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
#
#
# [2024-06-17 19:22:25,199] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT forward /home/rrochas/uncertainty_quantification/dl_models/time_embedding.py line 94
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
#
#
# [2024-06-17 19:22:25,358] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT forward /home/rrochas/uncertainty_quantification/dl_models/time_embedding.py line 58
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
#
#
# [2024-06-17 19:22:26,394] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT forward /home/rrochas/uncertainty_quantification/dl_models/STGCN.py line 172
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
#
#
# [2024-06-17 19:22:26,550] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT forward /home/rrochas/uncertainty_quantification/dl_models/STGCN_layer.py line 88
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
#
#
# [2024-06-17 19:22:26,649] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT forward /home/rrochas/uncertainty_quantification/dl_models/STGCN_layer.py line 14
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
#
#
# [2024-06-17 19:22:26,762] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT forward /home/rrochas/uncertainty_quantification/dl_models/STGCN_layer.py line 52
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
#
#
# [2024-06-17 19:22:27,564] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT <graph break in forward> /home/rrochas/uncertainty_quantification/dl_models/STGCN_layer.py line 260
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
#
#
# [2024-06-17 19:22:27,682] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT forward /home/rrochas/uncertainty_quantification/dl_models/STGCN_layer.py line 230
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
#
#
# [2024-06-17 19:22:27,793] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT forward /home/rrochas/uncertainty_quantification/dl_models/STGCN_layer.py line 202
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
#
#
# [2024-06-17 19:22:27,979] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT <graph break in forward> /home/rrochas/uncertainty_quantification/dl_models/STGCN_layer.py line 290
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
# Max GPU memory allocated: 3.085141181945801 GB
# Max GPU memory cached: 4.84375 GB
# Max CPU memory allocated: 4.167446136474609 GB
# None
# torch training:  88.41666531562805

# %%
args.num_workers = 1
args.persistent_workers = True
args.pin_memory = True
args.prefetch_factor = 2

args.autocast = True
args.torch_compile = True
args.backend = 'cudagraphs'

trainer = complete_train(args,folder_path,file_name)
# Out:
# coverage period: 2019-01-01 00:00:00 - 2020-01-01 00:00:00
# Time-step per hour: 4.0
# Time to compute 'get_DataSet_and_invalid_dates': 0.1690845489501953
# Time to compute 'split_K_fold': 7.8700408935546875
# Time to compute 'get_MultiModel_loss_args_emb_opts': 1.5556645393371582
# start training
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# Max GPU memory allocated: 31.74046754837036 GB
# Max GPU memory cached: 42.619140625 GB
# Max CPU memory allocated: 4.212139129638672 GB
# None
# torch training:  116.21545314788818

# %% [markdown]
# # Test sur CNN
# ## Test sur 'memory_format = torch.channels_last':
# Pas/peu concluant.

# %% [markdown]
# ### Batch_size = 32

# %%
t1 = time.time()
trainer = Trainer(Datasets[0],model,data_loader,args,optimizer,loss_function,scheduler = None,args_embedding = args_embedding)
trainer.train_and_valid(mod = None, mod_plot = None,station = 0)
print('torch training: ',time.time()-t1)
pd.DataFrame({'valid': trainer.valid_loss}).plot()
# Out:
# start training
#
# Max GPU memory allocated: 0.2725052833557129 GB
# Max GPU memory cached: 0.3203125 GB
# Max CPU memory allocated: 4.090812683105469 GB
# None
# torch training:  69.90467357635498
# <Axes: >

# %% [markdown]
# ### Batch-size = 256

# %%
t1 = time.time()
trainer = Trainer(Datasets[0],model,data_loader,args,optimizer,loss_function,scheduler = None,args_embedding = args_embedding)
trainer.train_and_valid(mod = None, mod_plot = None,station = 0)
print('torch training: ',time.time()-t1)
pd.DataFrame({'valid': trainer.valid_loss}).plot()
# Out:
# start training
#
# Max GPU memory allocated: 0.2725052833557129 GB
# Max GPU memory cached: 0.3203125 GB
# Max CPU memory allocated: 4.396026611328125 GB
# None
# torch training:  27.118371963500977
# <Axes: >

# %%
# Out:
# <Axes: >

# %%
5760/40
# Out:
# 144.0
