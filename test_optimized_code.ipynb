# %%
import torch 
import time
from utilities_DL import get_DataSet_and_invalid_dates,get_MultiModel_loss_args_emb_opts
from DL_class import MultiModelTrainer, Trainer
from config import get_args
from plotting import plot_k_fold_split
from save_results import update_results_df
from paths import folder_path,file_name

import torch.nn as nn
import torch.nn.functional as F
import pandas as pd

# Load config
model_name = 'STGCN' #'CNN'
args = get_args(model_name)

# Modification : 
args.epochs = 50
args.K_fold = 6
args.batch_size = 256
args.ray = False
args.track_pi = False # Sinon 30% du temps consommé pour track le PI.
# Memory format: Channel last
args.memory_format_last = True
# ...

# Mixed Precision:
args.mixed_precision = False
# ...

# Torch Compile:
args.torch_compile = False
# ...

# x.to('cuda', non_blocking = True)
args.non_blocking = False
# ...

# DataLoader and Num workers
args.num_workers = 0
args.persistent_workers = False
args.pin_memory = False
args.prefetch_factor = None
args.drop_last = False
# ...

def complete_train(args,folder_path,file_name):
    # Load Multi-DataSet,k_fold split:
    t0 = time.time()
    dataset,invalid_dates = get_DataSet_and_invalid_dates(args.abs_path, folder_path,file_name,args.W,args.D,args.H,args.step_ahead,single_station = False)
    print(f"Time to compute 'get_DataSet_and_invalid_dates': {time.time()-t0}")

    t0 = time.time()
    (Datasets,DataLoader_list,time_slots_labels_list,dic_class2rpz_list,dic_rpz2class_list,nb_words_embedding_list) =  dataset.split_K_fold(args,invalid_dates)
    print(f"Time to compute 'split_K_fold': {time.time()-t0}")

    t0 = time.time()
    (loss_function,Model_list,Optimizer_list,Scheduler_list,args_embedding) = get_MultiModel_loss_args_emb_opts(args,nb_words_embedding_list,dic_class2rpz_list,n_vertex = len(Datasets[0].columns))
    print(f"Time to compute 'get_MultiModel_loss_args_emb_opts': {time.time()-t0}")

    # Get First dataset, dataloader etc:
    model = Model_list[0].to(args.device)
    data_loader = DataLoader_list[0]
    optimizer = Optimizer_list[0]
    dic_class2rpz = dic_class2rpz_list[0]
    
    t1 = time.time()
    if args.torch_compile:
        model = torch.compile(model,backend=args.backend)
    trainer = Trainer(Datasets[0],model,data_loader,args,optimizer,loss_function,scheduler = None,args_embedding = args_embedding)
    trainer.train_and_valid(mod = None, mod_plot = None,station = 0)
    print('torch training: ',time.time()-t1)
    pd.DataFrame({'valid': trainer.valid_loss}).plot()
    
    return(trainer)
# Out:
# Training and Hyper-parameter tuning with Ray is not possible

# %%
def prefetch_to_device(self,loader):
        return [(x.to(self.args.device, non_blocking=self.args.non_blocking), y.to(self.args.device, non_blocking=self.args.non_blocking), [t.to(self.args.device, non_blocking=self.args.non_blocking) for t in T])
        for x, y, *T in loader]

# %%
# Out:
# 14

# %% [markdown]
# # Test sur STGCN
# ## Sans optimisation :

# %%
args.num_workers = 0
args.persistent_workers = False
args.pin_memory = False
args.prefetch_factor = None

args.autocast = False

args.non_blocking = False
args.torch_compile = False

trainer = complete_train(args,folder_path,file_name)
# Out:
# coverage period: 2019-01-01 00:00:00 - 2020-01-01 00:00:00
# Time-step per hour: 4.0
# Time to compute 'get_DataSet_and_invalid_dates': 0.179579496383667
# Time to compute 'split_K_fold': 8.698919773101807
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# Time to compute 'get_MultiModel_loss_args_emb_opts': 1.5981898307800293
# start training
# Training Throughput:11395.60 sequences per seconds
# >>> Training complete in: 0:00:49.191622
# >>> Training performance time: min 0.028942108154296875 avg 0.042690277099609375 seconds (+/- 0.0034371983880047323)
# >>> Loading performance time: min 0.0032720565795898438 avg 0.03425687551498413 seconds (+/- 0.08115671450546727)
# >>> Forward performance time: 0.02604648654211915 seconds (+/- 0.003160530580188543)
# >>> Backward performance time: 0.01006018279789173 seconds (+/- 0.0005591562590936366)
# >>> Plotting performance time: 1.921945688675861e-06 seconds (+/- 2.742106146443692e-07)
# >>> Saving performance time: 0.02726266860961914 seconds (+/- 0.017966277700377977)
# >>> PI-tracking performance time: 6.213480112503986e-06 seconds (+/- 6.966607926755757e-06)
# >>> Scheduler-update performance time: 3.5762786865234375e-06 seconds (+/- 5.678903034936723e-07)
# >>> Peak Power during training: 198.116 W)
# Proportion of time consumed for Loading: 45.3%
# Proportion of time consumed for Forward: 36.3%
# Proportion of time consumed for Backward: 13.1%
# Proportion of time consumed for Plotting: 0.0%
# Proportion of time consumed for CheckPoint Saving: 5.2%
# Proportion of time consumed for Tracking PI: 0.0%
# Proportion of time consumed for Update Scheduler: 0.0%
#
# Max GPU memory allocated: 0.5770678520202637 GB
# Max GPU memory cached: 0.97265625 GB
# Max CPU memory allocated: 4.117191314697266 GB
# None
# torch training:  49.19545245170593

# %% [markdown]
# ## Après optimisation
#
# ### Utilisation de num-workers = 1:
# Peu d'amélioration notable

# %%
args.num_workers = 1
args.persistent_workers = True
args.pin_memory = True
args.prefetch_factor = 2

args.autocast = False
args.non_blocking = False
args.torch_compile = False

trainer = complete_train(args,folder_path,file_name)
# Out:
# coverage period: 2019-01-01 00:00:00 - 2020-01-01 00:00:00
# Time-step per hour: 4.0
# Time to compute 'get_DataSet_and_invalid_dates': 0.1614682674407959
# Time to compute 'split_K_fold': 8.283355951309204
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# Time to compute 'get_MultiModel_loss_args_emb_opts': 0.06195569038391113
# start training
# Training Throughput:11431.327620155931 sequences per seconds
# >>> Training complete in: 0:00:46.143973
# >>> Training performance time: min 0.03181266784667969 avg 0.0439600944519043 seconds (+/- 0.0027627327104850987)
# >>> Loading performance time: min 0.00017952919006347656 avg 0.03160180340814327 seconds (+/- 0.05006715818738918)
# >>> Forward performance time: 0.02716703510420858 seconds (+/- 0.0019315382665518674)
# >>> Backward performance time: 0.011246467352936707 seconds (+/- 0.00125084525710182)
# >>> Plotting performance time: 1.887885891661352e-06 seconds (+/- 3.7569896722318616e-07)
# >>> Saving performance time: 0.03347261905670166 seconds (+/- 0.03074808795931178)
# >>> PI-tracking performance time: 6.004255645129146e-06 seconds (+/- 2.510127767376547e-06)
# >>> Scheduler-update performance time: 4.2526089415258295e-06 seconds (+/- 8.458179037696685e-07)
# >>> Peak Power during training: 208.802 W)
# Proportion of time consumed for Loading: 44.5%
# Proportion of time consumed for Forward: 36.9%
# Proportion of time consumed for Backward: 15.3%
# Proportion of time consumed for Plotting: 0.0%
# Proportion of time consumed for CheckPoint Saving: 3.3%
# Proportion of time consumed for Tracking PI: 0.0%
# Proportion of time consumed for Update Scheduler: 0.0%
#
# Max GPU memory allocated: 2.722041606903076 GB
# Max GPU memory cached: 4.751953125 GB
# Max CPU memory allocated: 4.293754577636719 GB
# None
# torch training:  46.14727306365967

# %% [markdown]
# ### Utilisation de Mixed-precision avec autocast()
# Peu d'amélioration notable

# %%
args.num_workers = 0
args.persistent_workers = 0
args.pin_memory = 0
args.prefetch_factor = None

args.autocast = True
args.non_blocking = False
args.torch_compile = False

trainer = complete_train(args,folder_path,file_name)
# Out:
# coverage period: 2019-01-01 00:00:00 - 2020-01-01 00:00:00
# Time-step per hour: 4.0
# Time to compute 'get_DataSet_and_invalid_dates': 0.17840862274169922
# Time to compute 'split_K_fold': 8.908262014389038
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# Time to compute 'get_MultiModel_loss_args_emb_opts': 0.0683145523071289
# start training
# Training Throughput:11213.887322096887 sequences per seconds
# >>> Training complete in: 0:00:49.219602
# >>> Training performance time: min 0.034957170486450195 avg 0.04485726356506348 seconds (+/- 0.0027549648456789903)
# >>> Loading performance time: min 0.0031397342681884766 avg 0.03378469147076264 seconds (+/- 0.05066469103546835)
# >>> Forward performance time: 0.02733883291525561 seconds (+/- 0.0015780570509746066)
# >>> Backward performance time: 0.011880330261754375 seconds (+/- 0.0018716224492037515)
# >>> Plotting performance time: 1.7613780741788902e-06 seconds (+/- 3.0393985216454907e-07)
# >>> Saving performance time: 0.028210725784301758 seconds (+/- 0.015954759929405888)
# >>> PI-tracking performance time: 5.906941939373406e-06 seconds (+/- 3.4267830083312125e-06)
# >>> Scheduler-update performance time: 4.520221632354113e-06 seconds (+/- 2.7523010220466245e-06)
# >>> Peak Power during training: 211.389 W)
# Proportion of time consumed for Loading: 45.8%
# Proportion of time consumed for Forward: 35.9%
# Proportion of time consumed for Backward: 15.6%
# Proportion of time consumed for Plotting: 0.0%
# Proportion of time consumed for CheckPoint Saving: 2.7%
# Proportion of time consumed for Tracking PI: 0.0%
# Proportion of time consumed for Update Scheduler: 0.0%
#
# Max GPU memory allocated: 2.722041606903076 GB
# Max GPU memory cached: 4.751953125 GB
# Max CPU memory allocated: 4.296367645263672 GB
# None
# torch training:  49.2218964099884

# %% [markdown]
# ## Utilisation de Non-Blocking:

# %%
args.num_workers = 0
args.persistent_workers = 0
args.pin_memory = 0
args.prefetch_factor = None

args.autocast = False
args.non_blocking = True
args.torch_compile = False

trainer = complete_train(args,folder_path,file_name)
# Out:
# coverage period: 2019-01-01 00:00:00 - 2020-01-01 00:00:00
# Time-step per hour: 4.0
# Time to compute 'get_DataSet_and_invalid_dates': 0.163374662399292
# Time to compute 'split_K_fold': 8.111580848693848
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# Time to compute 'get_MultiModel_loss_args_emb_opts': 0.060918331146240234
# start training
# Training Throughput:11399.575958137226 sequences per seconds
# >>> Training complete in: 0:00:48.609475
# >>> Training performance time: min 0.03507256507873535 avg 0.043331146240234375 seconds (+/- 0.0029338066823931365)
# >>> Loading performance time: min 0.003125905990600586 avg 0.03343159651888009 seconds (+/- 0.05043820320187786)
# >>> Forward performance time: 0.027179553955580204 seconds (+/- 0.001536661752723583)
# >>> Backward performance time: 0.011382435183327256 seconds (+/- 0.0016858891574851656)
# >>> Plotting performance time: 1.7905721859056123e-06 seconds (+/- 4.3383799037463827e-07)
# >>> Saving performance time: 0.03382739543914795 seconds (+/- 0.0256486721357956)
# >>> PI-tracking performance time: 7.001721129125479e-06 seconds (+/- 4.876785850585562e-06)
# >>> Scheduler-update performance time: 4.787834323182398e-06 seconds (+/- 2.751827879372857e-06)
# >>> Peak Power during training: 214.825 W)
# Proportion of time consumed for Loading: 45.7%
# Proportion of time consumed for Forward: 35.9%
# Proportion of time consumed for Backward: 15.1%
# Proportion of time consumed for Plotting: 0.0%
# Proportion of time consumed for CheckPoint Saving: 3.3%
# Proportion of time consumed for Tracking PI: 0.0%
# Proportion of time consumed for Update Scheduler: 0.0%
#
# Max GPU memory allocated: 2.722041606903076 GB
# Max GPU memory cached: 4.751953125 GB
# Max CPU memory allocated: 4.290592193603516 GB
# None
# torch training:  48.611645221710205

# %% [markdown]
# ## Utilisation des 3:
# Toujours d'aucune utilité

# %%
args.num_workers = 1
args.persistent_workers = True
args.pin_memory = True
args.prefetch_factor = 2

args.autocast = True
args.non_blocking = True
args.torch_compile = False

trainer = complete_train(args,folder_path,file_name)
# Out:
# coverage period: 2019-01-01 00:00:00 - 2020-01-01 00:00:00
# Time-step per hour: 4.0
# Time to compute 'get_DataSet_and_invalid_dates': 0.16352200508117676
# Time to compute 'split_K_fold': 8.194646120071411
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# number of total parameters: 273358
# number of trainable parameters: 273358
# Time to compute 'get_MultiModel_loss_args_emb_opts': 0.060808420181274414
# start training
# Training Throughput:11671.418500841499 sequences per seconds
# >>> Training complete in: 0:00:44.978472
# >>> Training performance time: min 0.030539751052856445 avg 0.04335308074951172 seconds (+/- 0.0029431256941643918)
# >>> Loading performance time: min 0.0001304149627685547 avg 0.030797357717271667 seconds (+/- 0.05017707304049759)
# >>> Forward performance time: 0.026898936993403837 seconds (+/- 0.0023931614153375005)
# >>> Backward performance time: 0.010622525931427918 seconds (+/- 0.0008922094584463767)
# >>> Plotting performance time: 2.1506328972018497e-06 seconds (+/- 7.438612818732106e-07)
# >>> Saving performance time: 0.029356751441955566 seconds (+/- 0.020322144295010162)
# >>> PI-tracking performance time: 6.8070937176139985e-06 seconds (+/- 3.6652080455102848e-06)
# >>> Scheduler-update performance time: 4.802431379045759e-06 seconds (+/- 2.248978481186346e-06)
# >>> Peak Power during training: 214.886 W)
# Proportion of time consumed for Loading: 44.6%
# Proportion of time consumed for Forward: 37.5%
# Proportion of time consumed for Backward: 14.8%
# Proportion of time consumed for Plotting: 0.0%
# Proportion of time consumed for CheckPoint Saving: 3.0%
# Proportion of time consumed for Tracking PI: 0.0%
# Proportion of time consumed for Update Scheduler: 0.0%
#
# Max GPU memory allocated: 2.722041606903076 GB
# Max GPU memory cached: 4.751953125 GB
# Max CPU memory allocated: 4.292476654052734 GB
# None
# torch training:  44.9832878112793

# %%
args.num_workers = 2
args.persistent_workers = True
args.pin_memory = True
args.prefetch_factor = 3

args.autocast = True
args.non_blocking = True
args.torch_compile = False

trainer = complete_train(args,folder_path,file_name)
# Out:
# coverage period: 2019-01-01 00:00:00 - 2020-01-01 00:00:00
# Time-step per hour: 4.0
# Time to compute 'get_DataSet_and_invalid_dates': 0.1846606731414795
# Time to compute 'split_K_fold': 8.191544532775879
# Time to compute 'get_MultiModel_loss_args_emb_opts': 0.06245303153991699
# start training

# %%
args.num_workers = 6
args.persistent_workers = True
args.pin_memory = True
args.prefetch_factor = 3

args.autocast = True
args.non_blocking = True
args.torch_compile = False

trainer = complete_train(args,folder_path,file_name)

# %% [markdown]
# ## Utilisation de Torch.compile:
# Inutile + explosions de la consommation Memoire GPU pour bakcend = 'cudagraphs'

# %%
import torch._dynamo as torchdynamo
torchdynamo.config.suppress_errors = True
torchdynamo.reset()

args.num_workers = 1
args.persistent_workers = True
args.pin_memory = True
args.prefetch_factor = 2

args.autocast = True
args.torch_compile = True
args.backend = 'inductor'

trainer = complete_train(args,folder_path,file_name)
# Out:
# coverage period: 2019-01-01 00:00:00 - 2020-01-01 00:00:00
# Time-step per hour: 4.0
# Time to compute 'get_DataSet_and_invalid_dates': 0.26770448684692383
# Time to compute 'split_K_fold': 7.876119613647461
# Time to compute 'get_MultiModel_loss_args_emb_opts': 1.544926404953003
# start training
# [2024-06-17 19:22:25,028] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT forward /home/rrochas/uncertainty_quantification/dl_models/full_model.py line 21
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
#
#
# [2024-06-17 19:22:25,199] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT forward /home/rrochas/uncertainty_quantification/dl_models/time_embedding.py line 94
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
#
#
# [2024-06-17 19:22:25,358] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT forward /home/rrochas/uncertainty_quantification/dl_models/time_embedding.py line 58
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
#
#
# [2024-06-17 19:22:26,394] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT forward /home/rrochas/uncertainty_quantification/dl_models/STGCN.py line 172
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
#
#
# [2024-06-17 19:22:26,550] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT forward /home/rrochas/uncertainty_quantification/dl_models/STGCN_layer.py line 88
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
#
#
# [2024-06-17 19:22:26,649] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT forward /home/rrochas/uncertainty_quantification/dl_models/STGCN_layer.py line 14
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
#
#
# [2024-06-17 19:22:26,762] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT forward /home/rrochas/uncertainty_quantification/dl_models/STGCN_layer.py line 52
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
#
#
# [2024-06-17 19:22:27,564] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT <graph break in forward> /home/rrochas/uncertainty_quantification/dl_models/STGCN_layer.py line 260
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
#
#
# [2024-06-17 19:22:27,682] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT forward /home/rrochas/uncertainty_quantification/dl_models/STGCN_layer.py line 230
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
#
#
# [2024-06-17 19:22:27,793] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT forward /home/rrochas/uncertainty_quantification/dl_models/STGCN_layer.py line 202
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
#
#
# [2024-06-17 19:22:27,979] torch._dynamo.convert_frame: [ERROR] WON'T CONVERT <graph break in forward> /home/rrochas/uncertainty_quantification/dl_models/STGCN_layer.py line 290
# due to:
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 25, in <module>
#     from pkg_resources import packaging  # type: ignore[attr-defined]
# ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_dynamo/output_graph.py", line 675, in call_user_compiler
#     raise BackendCompilerFailed(self.compiler_fn, e) from e
# torch._dynamo.exc.BackendCompilerFailed: debug_wrapper raised ImportError: cannot import name 'packaging' from 'pkg_resources' (/root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/pkg_resources/__init__.py)
#
# Set torch._dynamo.config.verbose=True for more information
# Max GPU memory allocated: 3.085141181945801 GB
# Max GPU memory cached: 4.84375 GB
# Max CPU memory allocated: 4.167446136474609 GB
# None
# torch training:  88.41666531562805

# %%
args.num_workers = 1
args.persistent_workers = True
args.pin_memory = True
args.prefetch_factor = 2

args.autocast = True
args.torch_compile = True
args.backend = 'cudagraphs'

trainer = complete_train(args,folder_path,file_name)
# Out:
# coverage period: 2019-01-01 00:00:00 - 2020-01-01 00:00:00
# Time-step per hour: 4.0
# Time to compute 'get_DataSet_and_invalid_dates': 0.1690845489501953
# Time to compute 'split_K_fold': 7.8700408935546875
# Time to compute 'get_MultiModel_loss_args_emb_opts': 1.5556645393371582
# start training
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/cuda/graphs.py:79: UserWarning: The CUDA Graph is empty. This ususally means that the graph was attempted to be captured on wrong device or stream. (Triggered internally at ../aten/src/ATen/cuda/CUDAGraph.cpp:191.)
#   super().capture_end()
# /root/anaconda3/envs/pytorch-2.0.1_py-3.10.5/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:1253: UserWarning: Your compiler for AOTAutograd is returning a a function that doesn't take boxed arguments. Please wrap it with functorch.compile.make_boxed_func or handle the boxed arguments yourself. See https://github.com/pytorch/pytorch/pull/83137#issuecomment-1211320670 for rationale.
#   warnings.warn(
# Max GPU memory allocated: 31.74046754837036 GB
# Max GPU memory cached: 42.619140625 GB
# Max CPU memory allocated: 4.212139129638672 GB
# None
# torch training:  116.21545314788818

# %% [markdown]
# # Test sur CNN
# ## Test sur 'memory_format = torch.channels_last':
# Pas/peu concluant.

# %% [markdown]
# ### Batch_size = 32

# %%
t1 = time.time()
trainer = Trainer(Datasets[0],model,data_loader,args,optimizer,loss_function,scheduler = None,args_embedding = args_embedding)
trainer.train_and_valid(mod = None, mod_plot = None,station = 0)
print('torch training: ',time.time()-t1)
pd.DataFrame({'valid': trainer.valid_loss}).plot()
# Out:
# start training
#
# Max GPU memory allocated: 0.2725052833557129 GB
# Max GPU memory cached: 0.3203125 GB
# Max CPU memory allocated: 4.090812683105469 GB
# None
# torch training:  69.90467357635498
# <Axes: >

# %% [markdown]
# ### Batch-size = 256

# %%
t1 = time.time()
trainer = Trainer(Datasets[0],model,data_loader,args,optimizer,loss_function,scheduler = None,args_embedding = args_embedding)
trainer.train_and_valid(mod = None, mod_plot = None,station = 0)
print('torch training: ',time.time()-t1)
pd.DataFrame({'valid': trainer.valid_loss}).plot()
# Out:
# start training
#
# Max GPU memory allocated: 0.2725052833557129 GB
# Max GPU memory cached: 0.3203125 GB
# Max CPU memory allocated: 4.396026611328125 GB
# None
# torch training:  27.118371963500977
# <Axes: >

# %%
# Out:
# <Axes: >

# %%
5760/40
# Out:
# 144.0
